# %%
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage
import os

api_key = "cY14u0o1OOd7Qh5doo0RnpsmhGl9AjNg"
model = "mistral-large-latest"

client = MistralClient(api_key=api_key)

chat_response = client.chat(
    model=model,
    messages=[ChatMessage(role="user", content="Que es la vida?")]
)

OUT = (chat_response.choices[0].message.content)
OUT
# Out:
# 'La vida es un fenómeno complejo que se caracteriza por una serie de procesos y atributos comunes a todos los seres vivos, como el metabolismo, la homeostasis, la capacidad de crecer y reproducirse, y la respuesta a estímulos.\n\nDesde una perspectiva biológica, la vida se define como el conjunto de organismos que comparten un antepasado común y que poseen un material genético que se transmite de generación en generación, lo que permite la evolución por selección natural.\n\nLa vida puede tomar muchas formas diferentes, desde organismos unicelulares como las bacterias y los protozoos, hasta organismos pluricelulares como las plantas, los hongos y los animales. Todos los seres vivos interactúan con su entorno y forman parte de ecosistemas complejos que sustentan la vida en la Tierra.\n\nLa vida es también un tema de reflexión filosófica y científica, y ha sido objeto de numerosas teorías y debates a lo largo de la historia. Aún hay mucho que aprender sobre la naturaleza y el origen de la vida, y la búsqueda de vida extraterrestre es un área de investigación activa en la actualidad.'

# %%
from transformers import pipeline
from IPython.display import Audio


pipe = pipeline("text-to-speech", model="suno/bark-small")

text = OUT
output = pipe(text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %%
output
# Out:
# {'audio': array([[3.2079876e-03, 2.3504444e-03, 1.8938762e-03, ..., 7.7279465e-06,
#          2.2785851e-05, 2.6762298e-05]], dtype=float32),
#  'sampling_rate': 24000}

# %%
print("----------------------------------audio-----------------------------------")
Audio(output["audio"], rate=output["sampling_rate"])
# Out:
# ----------------------------------audio-----------------------------------
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
